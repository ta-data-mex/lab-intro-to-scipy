# %%
from scipy.linalg import solve
import numpy as np

# %%
#5x+6y=10  -10x-12y=-20      -5+(6*(5/2))=10
#2x+4y=8   10x+20y=40   8y=20 y=10/4 2x+4(10/4)=8 2x=8-10 x=2/-2 x=-1

a = np.array([[5,6],[2,4]])
b = np.array([10,8])

x = solve(a,b)
x
# Out:
# array([-1. ,  2.5])

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
rango = np.arange(-1,1.1,0.1)
rango
normal_d = norm()
normal_d

# %%
plt.plot(rango, norm.pdf(rango))
